# %% [markdown]
# Practical No. 03 - Implement Union, Intersection, Complement and
# Difference operations on fuzzy sets. Also
# create fuzzy relations by Cartesian product of any two fuzzy sets and
# perform max-min
# composition on any two fuzzy relations.

# %%
import numpy as np

# %%
def fuzzy_union(A,B):
    return np.maximum(A,B)

# %%
def fuzzy_intersection(A,B):
    return np.minimum(A,B)

# %%
def fuzzy_complement(A):
    return 1 - A

# %%
def fuzzy_diffrence(A,B):
    return np.maximum(A,1 - B)

# %%
def cartesian_product(A,B):
    return np.outer(A,B)

# %%
def max_min_compositions(R,S):
    return np.max(np.minimum.outer(R,S),axis = 1)

# %%
A =np.array([0.2,0.4,0.6,0.8])
B =np.array([0.3,0.5,0.7,0.9])

# %%
union_result = fuzzy_union(A,B)
intersection_result = fuzzy_intersection(A,B)
complement_A = fuzzy_complement(A)
diffrence_result = fuzzy_diffrence(A,B)
print("Union:",union_result)
print("Intersection:",intersection_result)
print("Complement of A:",complement_A)
print("Diffrence:",diffrence_result)
# Out:
# Union: [0.3 0.5 0.7 0.9]
# Intersection: [0.2 0.4 0.6 0.8]
# Complement of A: [0.8 0.6 0.4 0.2]
# Diffrence: [0.7 0.5 0.6 0.8]

# %%
R = np.array([0.2, 0.5, 0.4]) # Fuzzy relation R
S = np.array([0.6, 0.3, 0.7]) # Fuzzy relation S

# %%
# Cartesian product of fuzzy relations
cartesian_result = cartesian_product(R, S)

# %%
# Max-Min composition of fuzzy relations
composition_result = max_min_compositions(R, S)

# %%
print("Cartesian product of R and S:")
print(cartesian_result)
# Out:
# Cartesian product of R and S:
# [[0.12 0.06 0.14]
#  [0.3  0.15 0.35]
#  [0.24 0.12 0.28]]

# %%
print("Max-Min composition of R and S:")
print(composition_result)
# Out:
# Max-Min composition of R and S:
# [0.2 0.5 0.4]
