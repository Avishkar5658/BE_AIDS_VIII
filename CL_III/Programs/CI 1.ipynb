# %% [markdown]
# Practical No. 06 - Implementation of Clonal selection algorithm using
# Python.

# %%
# !pip install numpy
# !pip install matplotlib
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in C:\Users\avith\AppData\Roaming\Python\Python314\site-packages (2.4.4)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Using cached matplotlib-3.10.9-cp314-cp314-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\avith\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\avith\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\avith\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\avith\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in C:\Users\avith\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\avith\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\avith\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\avith\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.9-cp314-cp314-win_amd64.whl (8.3 MB)
# Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Installing collected packages: cycler, contourpy, matplotlib
#
#    ------------- -------------------------- 1/3 [contourpy]
#    ------------- -------------------------- 1/3 [contourpy]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    -------------------------- ------------- 2/3 [matplotlib]
#    ---------------------------------------- 3/3 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 matplotlib-3.10.9
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored

# %%
def objective_function(x):
    return x**2 + 3*x + 5 # Example function to minimize

# %%
def initialize_population(size, lower_bound, upper_bound):
    return np.random.uniform(lower_bound, upper_bound, size)

# %%
def evaluate_fitness(population):
    return 1 / (1 + objective_function(population)) # Inverse forminimization

# %%
def select_best(population, fitness, num_best):
    sorted_indices = np.argsort(-fitness) # Descending order
    return population[sorted_indices[:num_best]]

# %%
def clone_population(best_population, num_clones):
    clones = np.repeat(best_population, num_clones)
    return clones

# %%
def mutate(clones, mutation_rate):
    mutation = np.random.uniform(-mutation_rate, mutation_rate,
size=clones.shape)
    return clones + mutation

# %%
def replace_worst(population, new_population, num_replace):
    population[-num_replace:] = new_population[:num_replace]
    return population
